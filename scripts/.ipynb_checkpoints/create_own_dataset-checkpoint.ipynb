# %%
import math
import os
from PIL import Image
from sklearn.model_selection import train_test_split
import json
import yaml

# %%
#!python bop_toolkit/scripts/calc_gt_masks.py
#!python bop_toolkit/scripts/calc_gt_info.py

# %% [markdown]
# ## Create extra folders for every object

# %%
# Specify the folder path
path = "/home/max/Documents/GitHub/thesis/output/bop_data/chess/train/00000"

try:
    folder_path = path + "1"
    mask_path = path + "1/mask"
    mask_visib_path = path + "1/mask_visib"
    # Create the folders
    os.mkdir(folder_path)
    os.mkdir(mask_path)
    os.mkdir(mask_visib_path)


    folder_path = path + "2"
    mask_path = path + "2/mask"
    mask_visib_path = path + "2/mask_visib"
    # Create the folders
    os.mkdir(folder_path)
    os.mkdir(mask_path)
    os.mkdir(mask_visib_path)

    folder_path = path + "3"
    mask_path = path + "3/mask"
    mask_visib_path = path + "3/mask_visib"
    # Create the folders
    os.mkdir(folder_path)
    os.mkdir(mask_path)
    os.mkdir(mask_visib_path)

    folder_path = path + "4"
    mask_path = path + "4/mask"
    mask_visib_path = path + "4/mask_visib"
    # Create the folders
    os.mkdir(folder_path)
    os.mkdir(mask_path)
    os.mkdir(mask_visib_path)

    folder_path = path + "5"
    mask_path = path + "5/mask"
    mask_visib_path = path + "5/mask_visib"
    # Create the folders
    os.mkdir(folder_path)
    os.mkdir(mask_path)
    os.mkdir(mask_visib_path)

    folder_path = path + "6"
    mask_path = path + "6/mask"
    mask_visib_path = path + "6/mask_visib"
    # Create the folders
    os.mkdir(folder_path)
    os.mkdir(mask_path)
    os.mkdir(mask_visib_path)
except:
    print("directs already there")

current_dir = path.rstrip("/00000")
print(current_dir)
directories = [d for d in os.listdir(current_dir) if os.path.isdir(os.path.join(current_dir, d))]

directories
# Out:
# /home/max/Documents/GitHub/thesis/output/bop_data/chess/train
# ['000004', '000000', '000003', '000006', '000002', '000001', '000005']

# %% [markdown]
# ## Change format to linemod preprocessed and change scene_gt with all objects to every gt

# %%
scene_gt_path = path.rstrip("data/0") + "/000000/scene_gt.json"
print(scene_gt_path)
 
with open(scene_gt_path, 'r') as json_file:
    json_data = json.load(json_file)

# Filter the data and keep only items with obj_id equal to 1 :::: THE ROOK
filtered_data_1 = {key: [item for item in items if item['obj_id'] == 1] for key, items in json_data.items()}

# Filter the data and keep only items with obj_id equal to 1 :::: THE QUEEN
filtered_data_2 = {key: [item for item in items if item['obj_id'] == 2] for key, items in json_data.items()}

# Filter the data and keep only items with obj_id equal to 1 :::: THE PAWN
filtered_data_3 = {key: [item for item in items if item['obj_id'] == 3] for key, items in json_data.items()}

# Filter the data and keep only items with obj_id equal to 1 :::: THE KING
filtered_data_4 = {key: [item for item in items if item['obj_id'] == 4] for key, items in json_data.items()}

# Filter the data and keep only items with obj_id equal to 1 :::: THE HORSE
filtered_data_5 = {key: [item for item in items if item['obj_id'] == 5] for key, items in json_data.items()}

# Filter the data and keep only items with obj_id equal to 1 :::: THE BISHOP
filtered_data_6 = {key: [item for item in items if item['obj_id'] == 6] for key, items in json_data.items()}
    
output_file_1 = path + "1" + "/scene_gt.json"
output_file_2 = path + "2" + "/scene_gt.json"
output_file_3 = path + "3" + "/scene_gt.json"
output_file_4 = path + "4" + "/scene_gt.json"
output_file_5 = path + "5" + "/scene_gt.json"
output_file_6 = path + "6" + "/scene_gt.json"

# Write the filtered_data dictionary to the output file as JSON
with open(output_file_1, 'w') as f:
    json.dump(filtered_data_1, f,indent=4)
    
with open(output_file_2, 'w') as f:
    json.dump(filtered_data_2, f,indent=4)
    
with open(output_file_3, 'w') as f:
    json.dump(filtered_data_3, f,indent=4)

with open(output_file_4, 'w') as f:
    json.dump(filtered_data_4, f,indent=4)
    
with open(output_file_5, 'w') as f:
    json.dump(filtered_data_5, f,indent=4)

with open(output_file_6, 'w') as f:
    json.dump(filtered_data_6, f,indent=4)
# Out:
# /home/max/Documents/GitHub/thesis/output/bop_data/chess/train/000000/scene_gt.json

# %% [markdown]
# ## Give every folder the right masks

# %%
import os
import shutil

folder_path = path.rstrip("data/0") + "/train/000000/mask"

# Get the list of all files in the folder
files = os.listdir(folder_path)

# Define the list of destination folders
destination_folders = [
    path + "1/mask",
    path + "2/mask",
    path + "3/mask",
    path + "4/mask",
    path + "5/mask",
    path + "6/mask"
]

# Iterate over the destination folders
for i, destination_folder in enumerate(destination_folders, start=0):
    # Filter the files that end with "{i}.png"
    image_files = [file for file in files if file.endswith(f"{i}.png")]
    
    # Copy the image files to the destination folder
    for file in image_files:
        source_file = os.path.join(folder_path, file)
        destination_file = os.path.join(destination_folder, file)
        shutil.copyfile(source_file, destination_file)
        
print("Mask files copied successfully.")

folder_path = path.rstrip("data/0") + "/train/000000/mask_visib" # Specify the folder path

# Get the list of all files in the folder
files = os.listdir(folder_path)

# Define the list of destination folders
destination_folders = [
    path + "1/mask_visib",
    path + "2/mask_visib",
    path + "3/mask_visib",
    path + "4/mask_visib",
    path + "5/mask_visib",
    path + "6/mask_visib"
]

# Iterate over the destination folders
for i, destination_folder in enumerate(destination_folders, start=0):
    # Filter the files that end with "{i}.png"
    image_files = [file for file in files if file.endswith(f"{i}.png")]
    
    # Copy the image files to the destination folder
    for file in image_files:
        source_file = os.path.join(folder_path, file)
        destination_file = os.path.join(destination_folder, file)
        shutil.copyfile(source_file, destination_file)
        
print("Mask visible files copied successfully.")

import os
import shutil

folder_path = path.rstrip("data/0") + "/train/000000" # Specify the folder path

# Define the source file path
source_file_path = os.path.join(folder_path, "scene_camera.json")

# Define the list of destination folders
destination_folders = [
    path + "1",
    path + "2",
    path + "3",
    path + "4",
    path + "5",
    path + "6"
]

# Iterate over the destination folders
for i, destination_folder in enumerate(destination_folders, start=1):
    # Define the destination file path
    destination_file_path = os.path.join(destination_folder, "scene_camera.json")
    
    # Copy the source file to the destination folder
    shutil.copyfile(source_file_path, destination_file_path)
    
print("scene_camera.json copied successfully.")

try:
    # Specify the source directory
    source_dir = path.rstrip("data/0") + "/train/000000/rgb" 

    # Create symbolic links for each destination folder
    for folder in destination_folders:
        destination_path = os.path.join(folder, "rgb")
        os.symlink(source_dir, destination_path)
        #print(f"Symbolic link created from {source_dir} to {destination_path}")

    print("RGB Symbolic links created successfully.")
except: 
    None
    
try:
    # Specify the source directory
    source_dir = path.rstrip("data/0") + "/train/000000/depth" 

    # Create symbolic links for each destination folder
    for folder in destination_folders:
        destination_path = os.path.join(folder, "depth")
        os.symlink(source_dir, destination_path)
        #print(f"Symbolic link created from {source_dir} to {destination_path}")

    print("Depth Symbolic links created successfully.")
except: 
    None
# Out:
# Mask files copied successfully.
# Mask visible files copied successfully.
# scene_camera.json copied successfully.
# RGB Symbolic links created successfully.
# Depth Symbolic links created successfully.

# %%
# !python /home/max/Documents/GitHub/thesis/bop_toolkit/scripts/calc_gt_info.py
# Out:
# 6/12|10:31:49: Initializing renderer...
# vispy uses app: egl, gl: gl2
# Traceback (most recent call last):
#   File "/home/max/Documents/GitHub/thesis/bop_toolkit/scripts/calc_gt_info.py", line 87, in <module>
#     scene_camera = inout.load_scene_camera(
#   File "/home/max/Documents/GitHub/thesis/bop_toolkit/scripts/bop_toolkit_lib/inout.py", line 148, in load_scene_camera
#     scene_camera = load_json(path, keys_to_int=True)
#   File "/home/max/Documents/GitHub/thesis/bop_toolkit/scripts/bop_toolkit_lib/inout.py", line 76, in load_json
#     with open(path, 'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/home/max/Documents/GitHub/thesis/output/bop_data/chess/data/000001/scene_camera.json'

# %%
try:
    folders = ['/home/max/Documents/blenderproc/output/bop_data/chess/train/000001', '/home/max/Documents/blenderproc/output/bop_data/chess/train/000002', '/home/max/Documents/blenderproc/output/bop_data/chess/train/000003', '/home/max/Documents/blenderproc/output/bop_data/chess/train/000004', '/home/max/Documents/blenderproc/output/bop_data/chess/train/000005', '/home/max/Documents/blenderproc/output/bop_data/chess/train/000006']
    new_folders = ['/home/max/Documents/blenderproc/output/bop_data/chess/train/01', '/home/max/Documents/blenderproc/output/bop_data/chess/train/02', '/home/max/Documents/blenderproc/output/bop_data/chess/train/03', '/home/max/Documents/blenderproc/output/bop_data/chess/train/04', '/home/max/Documents/blenderproc/output/bop_data/chess/train/05', '/home/max/Documents/blenderproc/output/bop_data/chess/train/06']

    # Rename the folders
    for folder, new_folder in zip(folders, new_folders):
        os.rename(folder, new_folder)
        print(folder,new_folder)
    
except:
    None
current_dir = os.getcwd() + "/output/bop_data/chess/train"
directories = [d for d in os.listdir(current_dir) if os.path.isdir(os.path.join(current_dir, d))]
directories
# Out:
# ['06', '03', '05', '02', '01', '04']

# %% [markdown]
# ## Create gt.yml & info.yml files from scene_gt.json and scene_gt_info.json

# %%
for directory in directories:
    json_file_dataset = current_dir + "/" + directory + "/scene_gt.json"
    json_file_bbox = current_dir + "/" + directory + "/scene_gt_info.json"

    output_file = current_dir + "/" + directory + "/gt.yml"
    # Open the JSON file and load its contents as a dictionary
    with open(json_file_dataset, 'r') as json_file:
        json_data = json.load(json_file)
        
    with open(json_file_bbox, 'r') as json_file:
        json_data_bbox = json.load(json_file)
        
    # Convert to YAML string
    yaml_str = ''
    for k, v in json_data.items():
        yaml_str += f"{k}: \n"
        yaml_str += f"- cam_R_m2c: {v[0]['cam_R_m2c']}\n"
        yaml_str += f"  cam_t_m2c: {v[0]['cam_t_m2c']}\n"
        yaml_str += f"  obj_bb: {json_data_bbox[str(k)][0]['bbox_obj']}\n"
        yaml_str += f"  obj_id: {v[0]['obj_id']}\n"

    
    # Convert the dictionary to YAML format
    yaml_data = yaml.dump(json_data, default_flow_style=False)

    # Write the YAML data to a file
    with open(output_file, 'w') as yaml_file:
        yaml_file.write(yaml_str)
        
    json_file_info = current_dir + "/" + directory + "/scene_camera.json"
    with open(json_file_info, 'r') as json_file:
        json_data = json.load(json_file)
    
    yaml_str = ''
    for k, v in json_data.items():
        yaml_str += f"{k}: \n"
        yaml_str += f" cam_K: {v['cam_K']}\n"
        yaml_str += f" depth_scale: {v['depth_scale']}\n"

    yaml_data = yaml.dump(json_data, default_flow_style=False)
    
    info_file = current_dir + "/" + directory + "/info.yml"
    # Write the YAML data to a file
    with open(info_file, 'w') as yaml_file:
        yaml_file.write(yaml_str)

# %% [markdown]
# ### Rename images to efficientpose like images and create train and test files

# %%
visib_fract_threshold = 0.3 #20% needs to be visible for the test or train dataset

for directory in directories:
    direc_rgb = current_dir + "/" + directory + "/rgb"
    direc_depth = current_dir + "/" + directory + "/depth"
    direc_mask = current_dir + "/" + directory + "/mask"
    direc_mask_visib = current_dir + "/" + directory + "/mask_visib"
    
    
    for filename in os.listdir(direc_mask):
        if len(filename) == 17:
            # Get the first 6 characters of the filename
            new_filename = filename[2:6] + ".png"
            # Rename the file
            os.rename(os.path.join(direc_mask, filename), os.path.join(direc_mask, new_filename))
        else: 
            break

    for filename in os.listdir(direc_mask_visib):
        if len(filename) == 17:
            # Get the first 6 characters of the filename
            new_filename = filename[2:6] + ".png"
            # Rename the file
            os.rename(os.path.join(direc_mask_visib, filename), os.path.join(direc_mask_visib, new_filename))
        else:
            break
            
    for filename in os.listdir(direc_rgb):
        if len(filename) == 10:
            # Get the first 6 characters of the filename
            new_filename = filename[2:]
            # Rename the file
            os.rename(os.path.join(direc_rgb, filename), os.path.join(direc_rgb, new_filename))
        else:
            break
        
    for filename in os.listdir(direc_depth):
        if len(filename) == 10:
            # Get the first 6 characters of the filename
            new_filename = filename[2:]
            # Rename the file
            os.rename(os.path.join(direc_depth, filename), os.path.join(direc_depth, new_filename))
        else: 
            break
            
    # Open the JSON file and load its contents as a dictionary
    output_file = current_dir + "/" + directory + "/scene_gt_info.json"
        
    with open(output_file, 'r') as json_file:
        json_data = json.load(json_file)
        
    all_images_threshold = []
    for key, value in json_data.items():
        for i, v in enumerate(value):
            if v['visib_fract'] > visib_fract_threshold:
                image_threshold = '{:04d}'.format(int(key))
                all_images_threshold.append(image_threshold)
                
    train_list, test_list = train_test_split(all_images_threshold, test_size=0.3, random_state=42)
    
    #train file
    filename = "train.txt"
    folder =  current_dir + "/" + directory
    filepath = os.path.join(folder, filename)
    with open(filepath, "w") as f:
        f.write('\n'.join(train_list))
        
    #Test file
    filename = "test.txt"
    folder =  current_dir + "/" + directory
    filepath = os.path.join(folder, filename)
    with open(filepath, "w") as f:
        f.write('\n'.join(test_list))
